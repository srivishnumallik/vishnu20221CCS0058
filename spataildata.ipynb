# %% [markdown]
# <a href="https://colab.research.google.com/github/srivishnumallik/vishnu20221CCS0058/blob/main/spataildata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.2.2)

# %%
import folium
mymap = folium.Map(location = [12.971599,77.594566],
                   width = 950,
                   height = 550,
                   zoom_start = 12,
                   titles = 'opendtreetmap')
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f985f5cc194a7510fa9d4b6f894f5698 {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f985f5cc194a7510fa9d4b6f894f5698&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f985f5cc194a7510fa9d4b6f894f5698 = L.map(
#                 &quot;map_f985f5cc194a7510fa9d4b6f894f5698&quot;,
#                 {
#                     center: [12.971599, 77.594566],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;opendtreetmap&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5fad08df577ef7becfb6c5fb24bf41e9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f985f5cc194a7510fa9d4b6f894f5698);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
mymap = folium.Map(location=[21.0404, 82.4509], zoom_start=5)

locations = {
    "Presidency university": (13.1018, 77.3210),
    "ISKCON temple": (13.0035, 77.3303),
    "Laalbagh lake": (12.5645, 77.3459),
    "PARLE BISCUITS FACTORY": (13.0256, 77.2936),
    "DL Track Peenya": (13.0212, 77.3141)
}

for location, coordinates in locations.items():
    folium.Marker(location=coordinates, popup=location).add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_238acff790a2d498be5bc75c96f3c433 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_238acff790a2d498be5bc75c96f3c433&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_238acff790a2d498be5bc75c96f3c433 = L.map(
#                 &quot;map_238acff790a2d498be5bc75c96f3c433&quot;,
#                 {
#                     center: [21.0404, 82.4509],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d46202b081816bd1848a677e0281d97a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_238acff790a2d498be5bc75c96f3c433);
#
#
#             var marker_b9190e338e406b2f4b3661c23cb4d7ea = L.marker(
#                 [13.1018, 77.321],
#                 {}
#             ).addTo(map_238acff790a2d498be5bc75c96f3c433);
#
#
#         var popup_6f5221f9655b52db1ba04e9e548ff313 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ee0af1557f20cad95ff6118fc768eb42 = $(`&lt;div id=&quot;html_ee0af1557f20cad95ff6118fc768eb42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Presidency university&lt;/div&gt;`)[0];
#                 popup_6f5221f9655b52db1ba04e9e548ff313.setContent(html_ee0af1557f20cad95ff6118fc768eb42);
#
#
#
#         marker_b9190e338e406b2f4b3661c23cb4d7ea.bindPopup(popup_6f5221f9655b52db1ba04e9e548ff313)
#         ;
#
#
#
#
#             var marker_beae0b27b95958e379c266b0eaaca95a = L.marker(
#                 [13.0035, 77.3303],
#                 {}
#             ).addTo(map_238acff790a2d498be5bc75c96f3c433);
#
#
#         var popup_1fc4e3416f4b3e9f4f06e5d9a7e76571 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ff9faea59675e6f17091f1d2fab71ce = $(`&lt;div id=&quot;html_4ff9faea59675e6f17091f1d2fab71ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ISKCON temple&lt;/div&gt;`)[0];
#                 popup_1fc4e3416f4b3e9f4f06e5d9a7e76571.setContent(html_4ff9faea59675e6f17091f1d2fab71ce);
#
#
#
#         marker_beae0b27b95958e379c266b0eaaca95a.bindPopup(popup_1fc4e3416f4b3e9f4f06e5d9a7e76571)
#         ;
#
#
#
#
#             var marker_c0b33327599e5ab38ad863e75c32e553 = L.marker(
#                 [12.5645, 77.3459],
#                 {}
#             ).addTo(map_238acff790a2d498be5bc75c96f3c433);
#
#
#         var popup_3c4cb6e9d431dee65ab7a93529a89135 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_042eb3e987c91a4cc871127859c257c5 = $(`&lt;div id=&quot;html_042eb3e987c91a4cc871127859c257c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Laalbagh lake&lt;/div&gt;`)[0];
#                 popup_3c4cb6e9d431dee65ab7a93529a89135.setContent(html_042eb3e987c91a4cc871127859c257c5);
#
#
#
#         marker_c0b33327599e5ab38ad863e75c32e553.bindPopup(popup_3c4cb6e9d431dee65ab7a93529a89135)
#         ;
#
#
#
#
#             var marker_5c7c022aa6e33fe4a63d88ec2b8a70ac = L.marker(
#                 [13.0256, 77.2936],
#                 {}
#             ).addTo(map_238acff790a2d498be5bc75c96f3c433);
#
#
#         var popup_e7aa1bcb1cc0ed730d3ea9680a13d3e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53cad1d74ca15a2c626c6dd08719a950 = $(`&lt;div id=&quot;html_53cad1d74ca15a2c626c6dd08719a950&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PARLE BISCUITS FACTORY&lt;/div&gt;`)[0];
#                 popup_e7aa1bcb1cc0ed730d3ea9680a13d3e8.setContent(html_53cad1d74ca15a2c626c6dd08719a950);
#
#
#
#         marker_5c7c022aa6e33fe4a63d88ec2b8a70ac.bindPopup(popup_e7aa1bcb1cc0ed730d3ea9680a13d3e8)
#         ;
#
#
#
#
#             var marker_f617014766bf299ae2c60c3c5734c7dd = L.marker(
#                 [13.0212, 77.3141],
#                 {}
#             ).addTo(map_238acff790a2d498be5bc75c96f3c433);
#
#
#         var popup_a12d9f9e471e7a1ce5aeadc32241c2a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_339099c84f69f67416ee0b6b182c651e = $(`&lt;div id=&quot;html_339099c84f69f67416ee0b6b182c651e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DL Track Peenya&lt;/div&gt;`)[0];
#                 popup_a12d9f9e471e7a1ce5aeadc32241c2a9.setContent(html_339099c84f69f67416ee0b6b182c651e);
#
#
#
#         marker_f617014766bf299ae2c60c3c5734c7dd.bindPopup(popup_a12d9f9e471e7a1ce5aeadc32241c2a9)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen web

# %%
import folium
#BANGLORE MAP WITH FAMOUS PLACES INCLUDING IMAGES
# Latitude and longitude coordinates of Bangalore
bangalore_coords = (12.9716, 77.5946)

# Create a map centered around Bangalore
map_bangalore = folium.Map(location=bangalore_coords, zoom_start=12)

# Define famous places and their coordinates in Bangalore

places = {
    "Lalbagh Botanical Garden": (12.9507, 77.5844),
    "Cubbon Park": (12.9757, 77.5929),
    "Bangalore Palace": (12.97194, 77.5936),
    "Vidhana Soudha": (12.979693, 77.590658),
    "Presidency University": (13.1682, 77.5354),
    "Wonderla": (12.834300, 77.414558)   ,
    "M Chinnaswamy Stadium": (12.9784, 77.5994),
    "Isckon temple": (13.00981, 77.55109),
    "Kempegowda International Airport": (13.192665896, 77.70333052)
}



# Define images for each place
images = {
    "Lalbagh Botanical Garden": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0c/7d/47/f4/lalbagh-botanical-garden.jpg?w=1200&h=1200&s=1",
    "Cubbon Park": "https://tse1.mm.bing.net/th?id=OIP.G-kjAcQb59k6I1vQ_XcHEwHaE8&pid=Api&P=0&h=180",
    "Bangalore Palace": "https://tse2.mm.bing.net/th?id=OIP.i8dzBHIHgsZ0D9JK9tzSMwHaEo&pid=Api&P=0&h=180",
    "Vidhana Soudha": "https://tse3.mm.bing.net/th?id=OIP.LMgE0-vo4Fk26srdnaMdYgHaFj&pid=Api&P=0&h=180",
    "Presidency University": "https://tse1.mm.bing.net/th?id=OIP.X_YkcFxJv_Hy_fDFMfJv-gHaE8&pid=Api&P=0&h=180",
    "Wonderla": "https://tse2.mm.bing.net/th?id=OIP.p-jWkEz-iJvmLc4PtPFwAAHaE8&pid=Api&P=0&h=180",
    "M Chinnaswamy Stadium": "https://tse1.mm.bing.net/th?id=OIP.NepFTWdG0NbPcLL2XFI-jQHaEK&pid=Api&P=0&h=180",
    "Isckon temple": "https://tse1.mm.bing.net/th?id=OIP.76ttZ61WrTg-a-nuYSpdPAHaFj&pid=Api&P=0&h=180",
    "Kempegowda International Airport": "https://tse4.mm.bing.net/th?id=OIP.tu4IQk62ZmQfQhbIPDfZ8AHaE8&pid=Api&P=0&h=180"
}

# Add markers for each place
for place, coords in places.items():
    popup_content = f'<b>{place}</b><br><img src="{images[place]}" width="200">'
    folium.Marker(location=coords, popup=folium.Popup(popup_content, max_width=300)).add_to(map_bangalore)

# Display the map
map_bangalore
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46c0123fe6e216c392b25e29f631ff7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46c0123fe6e216c392b25e29f631ff7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46c0123fe6e216c392b25e29f631ff7e = L.map(
#                 &quot;map_46c0123fe6e216c392b25e29f631ff7e&quot;,
#                 {
#                     center: [12.9716, 77.5946],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c9354002067abb326a2d9245f056015 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_46c0123fe6e216c392b25e29f631ff7e);
#
#
#             var marker_a200ef4de5628756c9dab846c21beba7 = L.marker(
#                 [12.9507, 77.5844],
#                 {}
#             ).addTo(map_46c0123fe6e216c392b25e29f631ff7e);
#
#
#         var popup_4e00580268cc25552fd9a579bf2169eb = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_a0f874104c029f8ae83b8545f1617ebf = $(`&lt;div id=&quot;html_a0f874104c029f8ae83b8545f1617ebf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Lalbagh Botanical Garden&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0c/7d/47/f4/lalbagh-botanical-garden.jpg?w=1200&amp;h=1200&amp;s=1&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_4e00580268cc25552fd9a579bf2169eb.setContent(html_a0f874104c029f8ae83b8545f1617ebf);
#
#
#
#         marker_a200ef4de5628756c9dab846c21beba7.bindPopup(popup_4e00580268cc25552fd9a579bf2169eb)
#         ;
#
#
#
#
#             var marker_42ff4fe4d93b0236a440730867a1f827 = L.marker(
#                 [12.9757, 77.5929],
#                 {}
#             ).addTo(map_46c0123fe6e216c392b25e29f631ff7e);
#
#
#         var popup_2887343ed0632034f1f9940b9af8974e = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_54faa9ff07e4360ce05a9775e7c2cd2e = $(`&lt;div id=&quot;html_54faa9ff07e4360ce05a9775e7c2cd2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Cubbon Park&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse1.mm.bing.net/th?id=OIP.G-kjAcQb59k6I1vQ_XcHEwHaE8&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_2887343ed0632034f1f9940b9af8974e.setContent(html_54faa9ff07e4360ce05a9775e7c2cd2e);
#
#
#
#         marker_42ff4fe4d93b0236a440730867a1f827.bindPopup(popup_2887343ed0632034f1f9940b9af8974e)
#         ;
#
#
#
#
#             var marker_c22518a11e13cf062bb201a672536fa6 = L.marker(
#                 [12.97194, 77.5936],
#                 {}
#             ).addTo(map_46c0123fe6e216c392b25e29f631ff7e);
#
#
#         var popup_2529e139ba50b33d8a98c3cd0addfaff = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_aca0b08c7ddb7b969d71a180f7607445 = $(`&lt;div id=&quot;html_aca0b08c7ddb7b969d71a180f7607445&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Bangalore Palace&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse2.mm.bing.net/th?id=OIP.i8dzBHIHgsZ0D9JK9tzSMwHaEo&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_2529e139ba50b33d8a98c3cd0addfaff.setContent(html_aca0b08c7ddb7b969d71a180f7607445);
#
#
#
#         marker_c22518a11e13cf062bb201a672536fa6.bindPopup(popup_2529e139ba50b33d8a98c3cd0addfaff)
#         ;
#
#
#
#
#             var marker_0d30af15d5506c8def4b5084d25f6b40 = L.marker(
#                 [12.979693, 77.590658],
#                 {}
#             ).addTo(map_46c0123fe6e216c392b25e29f631ff7e);
#
#
#         var popup_b5edce6ce0febc4b478914f8d4caa5c8 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_e9a74d826f34ae6a5bdfb18c6b38fba8 = $(`&lt;div id=&quot;html_e9a74d826f34ae6a5bdfb18c6b38fba8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Vidhana Soudha&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse3.mm.bing.net/th?id=OIP.LMgE0-vo4Fk26srdnaMdYgHaFj&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_b5edce6ce0febc4b478914f8d4caa5c8.setContent(html_e9a74d826f34ae6a5bdfb18c6b38fba8);
#
#
#
#         marker_0d30af15d5506c8def4b5084d25f6b40.bindPopup(popup_b5edce6ce0febc4b478914f8d4caa5c8)
#         ;
#
#
#
#
#             var marker_e34fc7affe6aa86de88632484fb38564 = L.marker(
#                 [13.1682, 77.5354],
#                 {}
#             ).addTo(map_46c0123fe6e216c392b25e29f631ff7e);
#
#
#         var popup_3439b707e111d7c6f9edf0411c11645e = L.popup({&
